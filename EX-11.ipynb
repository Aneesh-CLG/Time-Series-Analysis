# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

custom_column_names = ['WSR0', 'WSR1']

# Read without parsing dates first
df = pd.read_csv("eighthr.data.csv", header=None, na_values=['?'], names=custom_column_names + list(range(3, 74)))

# Convert 'WSR0' to datetime if needed
# df['WSR0'] = pd.to_datetime(df['WSR0'], format='%Y-%m-%d %H:%M:%S')

# %%
df.head(5)
# Out:
#           WSR0  WSR1    3    4    5    6    7    8    9   10  ...    64  \
# 1/1/1998   0.8   1.8  2.4  2.1  2.0  2.1  1.5  1.7  1.9  2.3  ...  0.15
# 1/2/1998   2.8   3.2  3.3  2.7  3.3  3.2  2.9  2.8  3.1  3.4  ...  0.48
# 1/3/1998   2.9   2.8  2.6  2.1  2.2  2.5  2.5  2.7  2.2  2.5  ...  0.60
# 1/4/1998   4.7   3.8  3.7  3.8  2.9  3.1  2.8  2.5  2.4  3.1  ...  0.49
# 1/5/1998   2.6   2.1  1.6  1.4  0.9  1.5  1.2  1.4  1.3  1.4  ...   NaN
#
#              65     66      67     68    69       70    71    72   73
# 1/1/1998  10.67  -1.56  5795.0 -12.10  17.9  10330.0 -55.0  0.00  0.0
# 1/2/1998   8.39   3.84  5805.0  14.05  29.0  10275.0 -55.0  0.00  0.0
# 1/3/1998   6.94   9.80  5790.0  17.90  41.3  10235.0 -40.0  0.00  0.0
# 1/4/1998   8.73  10.54  5775.0  31.15  51.7  10195.0 -40.0  2.08  0.0
# 1/5/1998    NaN    NaN     NaN    NaN   NaN      NaN   NaN  0.58  0.0
#
# [5 rows x 73 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#             WSR0  WSR1    3    4    5    6    7    8    9   10  ...    64  \
# 1/1/1998     0.8   1.8  2.4  2.1  2.0  2.1  1.5  1.7  1.9  2.3  ...  0.15
# 1/2/1998     2.8   3.2  3.3  2.7  3.3  3.2  2.9  2.8  3.1  3.4  ...  0.48
# 1/3/1998     2.9   2.8  2.6  2.1  2.2  2.5  2.5  2.7  2.2  2.5  ...  0.60
# 1/4/1998     4.7   3.8  3.7  3.8  2.9  3.1  2.8  2.5  2.4  3.1  ...  0.49
# 1/7/1998     3.7   3.2  3.8  5.1  6.0  7.0  6.3  6.4  6.3  5.4  ...  0.84
# ...          ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 12/27/2004   0.3   0.4  0.5  0.5  0.2  0.3  0.4  0.4  1.3  2.2  ...  0.07
# 12/28/2004   1.0   1.4  1.1  1.7  1.5  1.7  1.8  1.5  2.1  2.4  ...  0.04
# 12/29/2004   0.8   0.8  1.2  0.9  0.4  0.6  0.8  1.1  1.5  1.5  ...  0.06
# 12/30/2004   1.3   0.9  1.5  1.2  1.6  1.8  1.1  1.0  1.9  2.0  ...  0.25
# 12/31/2004   1.5   1.3  1.8  1.4  1.2  1.7  1.6  1.4  1.6  3.0  ...  0.54
#
#                65     66      67     68     69       70    71    72   73
# 1/1/1998    10.67  -1.56  5795.0 -12.10  17.90  10330.0 -55.0  0.00  0.0
# 1/2/1998     8.39   3.84  5805.0  14.05  29.00  10275.0 -55.0  0.00  0.0
# 1/3/1998     6.94   9.80  5790.0  17.90  41.30  10235.0 -40.0  0.00  0.0
# 1/4/1998     8.73  10.54  5775.0  31.15  51.70  10195.0 -40.0  2.08  0.0
# 1/7/1998     6.86  25.60  5695.0  26.75  48.45  10040.0 -80.0  0.18  0.0
# ...           ...    ...     ...    ...    ...      ...   ...   ...  ...
# 12/27/2004   7.93  -4.41  5800.0 -25.60  21.80  10295.0  65.0  0.00  0.0
# 12/28/2004   5.95  -1.14  5845.0 -19.40  19.10  10310.0  15.0  0.00  0.0
# 12/29/2004   7.80  -0.64  5845.0  -9.60  35.20  10275.0 -35.0  0.00  0.0
# 12/30/2004   7.72  -0.89  5845.0 -19.60  34.20  10245.0 -30.0  0.05  0.0
# 12/31/2004  13.07   9.15  5820.0   1.95  39.35  10220.0 -25.0  0.00  0.0
#
# [1847 rows x 73 columns]

# %%
df['WSR0']= df['WSR0'].astype(float)
df
# Out:
#             WSR0  WSR1    3    4    5    6    7    8    9   10  ...    64  \
# 1/1/1998     0.8   1.8  2.4  2.1  2.0  2.1  1.5  1.7  1.9  2.3  ...  0.15
# 1/2/1998     2.8   3.2  3.3  2.7  3.3  3.2  2.9  2.8  3.1  3.4  ...  0.48
# 1/3/1998     2.9   2.8  2.6  2.1  2.2  2.5  2.5  2.7  2.2  2.5  ...  0.60
# 1/4/1998     4.7   3.8  3.7  3.8  2.9  3.1  2.8  2.5  2.4  3.1  ...  0.49
# 1/7/1998     3.7   3.2  3.8  5.1  6.0  7.0  6.3  6.4  6.3  5.4  ...  0.84
# ...          ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 12/27/2004   0.3   0.4  0.5  0.5  0.2  0.3  0.4  0.4  1.3  2.2  ...  0.07
# 12/28/2004   1.0   1.4  1.1  1.7  1.5  1.7  1.8  1.5  2.1  2.4  ...  0.04
# 12/29/2004   0.8   0.8  1.2  0.9  0.4  0.6  0.8  1.1  1.5  1.5  ...  0.06
# 12/30/2004   1.3   0.9  1.5  1.2  1.6  1.8  1.1  1.0  1.9  2.0  ...  0.25
# 12/31/2004   1.5   1.3  1.8  1.4  1.2  1.7  1.6  1.4  1.6  3.0  ...  0.54
#
#                65     66      67     68     69       70    71    72   73
# 1/1/1998    10.67  -1.56  5795.0 -12.10  17.90  10330.0 -55.0  0.00  0.0
# 1/2/1998     8.39   3.84  5805.0  14.05  29.00  10275.0 -55.0  0.00  0.0
# 1/3/1998     6.94   9.80  5790.0  17.90  41.30  10235.0 -40.0  0.00  0.0
# 1/4/1998     8.73  10.54  5775.0  31.15  51.70  10195.0 -40.0  2.08  0.0
# 1/7/1998     6.86  25.60  5695.0  26.75  48.45  10040.0 -80.0  0.18  0.0
# ...           ...    ...     ...    ...    ...      ...   ...   ...  ...
# 12/27/2004   7.93  -4.41  5800.0 -25.60  21.80  10295.0  65.0  0.00  0.0
# 12/28/2004   5.95  -1.14  5845.0 -19.40  19.10  10310.0  15.0  0.00  0.0
# 12/29/2004   7.80  -0.64  5845.0  -9.60  35.20  10275.0 -35.0  0.00  0.0
# 12/30/2004   7.72  -0.89  5845.0 -19.60  34.20  10245.0 -30.0  0.05  0.0
# 12/31/2004  13.07   9.15  5820.0   1.95  39.35  10220.0 -25.0  0.00  0.0
#
# [1847 rows x 73 columns]

# %%
import matplotlib.pyplot as plt

# Create Figure and Axes
fig, axes = plt.subplots(2, 1, figsize=(14, 8))  # Correct way

# Plot data
df['WSR1'].plot(ax=axes[0], title='WSR0')  
df['WSR0'].plot(ax=axes[1], title='WSR1') 

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df['WSR0'])
print(result)
if result[1]<0.05:
    print("it is stationary")
else:
    print("it is non stationary")
# Out:
# (-6.41662374690127, 1.8344936186400462e-08, 17, 1829, {'1%': -3.4339303725739767, '5%': -2.863121534661253, '10%': -2.567611955063925}, 5719.420621835025)
# it is stationary

# %%
result = adfuller(df['WSR1'])
print(result)
if result[1]<0.05:
    print("it is stationary")
else:
    print("it is non stationary")
# Out:
# (-8.304325492921953, 3.940935898624488e-13, 10, 1836, {'1%': -3.4339167027591952, '5%': -2.8631154999882167, '10%': -2.5676087418063327}, 5704.177126615412)
# it is stationary

# %%
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.statespace.varmax import VARMAX

# %%
print('WSR0 causes WSR1')
print('--------------------')
granger1=grangercausalitytests(df[['WSR0','WSR1']],2)
print('WSR1 causes WSR0')
print('--------------------')
granger1=grangercausalitytests(df[['WSR1','WSR0']],2)
# Out:
# WSR0 causes WSR1
# --------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.1176  , p=0.0238  , df_denom=1843, df_num=1
# ssr based chi2 test:   chi2=5.1260  , p=0.0236  , df=1
# likelihood ratio test: chi2=5.1189  , p=0.0237  , df=1
# parameter F test:         F=5.1176  , p=0.0238  , df_denom=1843, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3865  , p=0.0922  , df_denom=1840, df_num=2
# ssr based chi2 test:   chi2=4.7860  , p=0.0914  , df=2
# likelihood ratio test: chi2=4.7798  , p=0.0916  , df=2
# parameter F test:         F=2.3865  , p=0.0922  , df_denom=1840, df_num=2
# WSR1 causes WSR0
# --------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=12.5489 , p=0.0004  , df_denom=1843, df_num=1
# ssr based chi2 test:   chi2=12.5693 , p=0.0004  , df=1
# likelihood ratio test: chi2=12.5267 , p=0.0004  , df=1
# parameter F test:         F=12.5489 , p=0.0004  , df_denom=1843, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.2531  , p=0.0020  , df_denom=1840, df_num=2
# ssr based chi2 test:   chi2=12.5402 , p=0.0019  , df=2
# likelihood ratio test: chi2=12.4977 , p=0.0019  , df=2
# parameter F test:         F=6.2531  , p=0.0020  , df_denom=1840, df_num=2

# %%
import pandas as pd
from statsmodels.tsa.api import VAR
from sklearn.model_selection import train_test_split


train, test = train_test_split(df[['WSR0', 'WSR1']], test_size=0.2, shuffle=False)

# Create and fit the VAR model
model = VAR(train)
sortedmodel = model.select_order(maxlags=20)
print(sortedmodel.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0      -0.8436     -0.8364      0.4301     -0.8409
# 1      -0.9681    -0.9464*      0.3798    -0.9600*
# 2      -0.9643     -0.9280      0.3813     -0.9508
# 3      -0.9626     -0.9119      0.3819     -0.9437
# 4      -0.9638     -0.8985      0.3814     -0.9395
# 5      -0.9671     -0.8874      0.3802     -0.9374
# 6      -0.9750     -0.8807      0.3772     -0.9398
# 7      -0.9711     -0.8623      0.3787     -0.9305
# 8      -0.9732     -0.8498      0.3779     -0.9271
# 9      -0.9709     -0.8331      0.3787     -0.9195
# 10    -0.9815*     -0.8292     0.3748*     -0.9247
# 11     -0.9810     -0.8142      0.3749     -0.9188
# 12     -0.9805     -0.7992      0.3751     -0.9129
# 13     -0.9782     -0.7824      0.3760     -0.9051
# 14     -0.9740     -0.7636      0.3776     -0.8955
# 15     -0.9724     -0.7475      0.3782     -0.8885
# 16     -0.9682     -0.7288      0.3798     -0.8789
# 17     -0.9671     -0.7132      0.3802     -0.8724
# 18     -0.9648     -0.6965      0.3811     -0.8647
# 19     -0.9620     -0.6791      0.3821     -0.8564
# 20     -0.9578     -0.6604      0.3837     -0.8469
# --------------------------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
var_model= VARMAX(train,order=(10,0),enforce_stationary=True)
fitmodel= var_model.fit()
fitmodel.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:       ['WSR0', 'WSR1']   No. Observations:                 1477
# Model:                        VAR(10)   Log Likelihood               -3429.409
#                           + intercept   AIC                           6948.819
# Date:                Thu, 03 Apr 2025   BIC                           7187.219
# Time:                        12:33:05   HQIC                          7037.700
# Sample:                             0
#                                - 1477
# Covariance Type:                  opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.05, 0.00   Jarque-Bera (JB):      157.93, 6920.64
# Prob(Q):                        0.82, 0.97   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.79, 0.94   Skew:                       0.75, 0.82
# Prob(H) (two-sided):            0.01, 0.51   Kurtosis:                  3.56, 13.48
#                           Results for equation WSR0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.6705      0.112      5.999      0.000       0.451       0.890
# L1.WSR0        0.2113      0.062      3.424      0.001       0.090       0.332
# L1.WSR1        0.1042      0.063      1.648      0.099      -0.020       0.228
# L2.WSR0       -0.0132      0.059     -0.225      0.822      -0.129       0.102
# L2.WSR1        0.0022      0.060      0.037      0.971      -0.115       0.119
# L3.WSR0       -0.0041      0.057     -0.072      0.942      -0.116       0.108
# L3.WSR1        0.0312      0.059      0.527      0.598      -0.085       0.147
# L4.WSR0       -0.0342      0.060     -0.567      0.571      -0.152       0.084
# L4.WSR1        0.0756      0.061      1.244      0.214      -0.044       0.195
# L5.WSR0       -0.0027      0.061     -0.044      0.965      -0.122       0.117
# L5.WSR1        0.0021      0.061      0.035      0.972      -0.117       0.121
# L6.WSR0        0.0518      0.061      0.856      0.392      -0.067       0.170
# L6.WSR1        0.0313      0.060      0.526      0.599      -0.085       0.148
# L7.WSR0       -0.0694      0.066     -1.046      0.295      -0.199       0.061
# L7.WSR1        0.0634      0.065      0.983      0.326      -0.063       0.190
# L8.WSR0       -0.1014      0.057     -1.780      0.075      -0.213       0.010
# L8.WSR1        0.1396      0.057      2.468      0.014       0.029       0.250
# L9.WSR0       -0.0072      0.064     -0.114      0.910      -0.132       0.118
# L9.WSR1        0.0126      0.064      0.197      0.844      -0.113       0.139
# L10.WSR0       0.1126      0.064      1.760      0.078      -0.013       0.238
# L10.WSR1       0.0104      0.063      0.165      0.869      -0.113       0.134
#                           Results for equation WSR1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.5977      0.111      5.394      0.000       0.381       0.815
# L1.WSR0        0.1753      0.062      2.818      0.005       0.053       0.297
# L1.WSR1        0.1317      0.064      2.062      0.039       0.007       0.257
# L2.WSR0        0.0105      0.056      0.188      0.851      -0.100       0.121
# L2.WSR1       -0.0173      0.057     -0.306      0.759      -0.128       0.093
# L3.WSR0       -0.0197      0.056     -0.349      0.727      -0.130       0.091
# L3.WSR1        0.0583      0.059      0.994      0.320      -0.057       0.173
# L4.WSR0        0.0060      0.062      0.097      0.923      -0.116       0.128
# L4.WSR1        0.0357      0.063      0.564      0.573      -0.088       0.160
# L5.WSR0       -0.0912      0.059     -1.550      0.121      -0.206       0.024
# L5.WSR1        0.0658      0.057      1.158      0.247      -0.046       0.177
# L6.WSR0        0.0503      0.064      0.790      0.429      -0.074       0.175
# L6.WSR1        0.0542      0.063      0.864      0.388      -0.069       0.177
# L7.WSR0       -0.0488      0.065     -0.748      0.455      -0.177       0.079
# L7.WSR1        0.0335      0.065      0.518      0.605      -0.093       0.160
# L8.WSR0       -0.0754      0.059     -1.270      0.204      -0.192       0.041
# L8.WSR1        0.1245      0.061      2.033      0.042       0.004       0.245
# L9.WSR0        0.0265      0.062      0.428      0.669      -0.095       0.148
# L9.WSR1       -0.0279      0.064     -0.437      0.662      -0.153       0.097
# L10.WSR0       0.0984      0.062      1.600      0.110      -0.022       0.219
# L10.WSR1       0.0317      0.061      0.520      0.603      -0.088       0.151
#                                Error covariance matrix
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# sqrt.var.WSR0          1.1910      0.023     51.178      0.000       1.145       1.237
# sqrt.cov.WSR0.WSR1     1.0724      0.024     44.840      0.000       1.025       1.119
# sqrt.var.WSR1          0.5010      0.005     96.792      0.000       0.491       0.511
# ======================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
n_forecast=12
pred=fitmodel.get_prediction()
preds=pred.predicted_mean

# %%
preds.columns=['WSR0 Predictions','WSR1 Predictions']
preds
# Out:
#            WSR0 Predictions  WSR1 Predictions
# 1/1/1998           1.668351          1.605051
# 1/2/1998           1.490838          1.457184
# 1/3/1998           2.122487          2.031586
# 1/4/1998           2.108596          2.044215
# 1/7/1998           2.697745          2.579086
# ...                     ...               ...
# 9/21/2003          1.807925          1.674507
# 9/22/2003          1.489603          1.376350
# 9/23/2003          1.425003          1.333773
# 9/24/2003          1.184023          1.239001
# 9/25/2003          0.970732          0.840566
#
# [1477 rows x 2 columns]

# %%
testvspred= pd.concat([train,preds],axis=1)
testvspred
# Out:
#            WSR0  WSR1  WSR0 Predictions  WSR1 Predictions
# 1/1/1998    0.8   1.8          1.668351          1.605051
# 1/2/1998    2.8   3.2          1.490838          1.457184
# 1/3/1998    2.9   2.8          2.122487          2.031586
# 1/4/1998    4.7   3.8          2.108596          2.044215
# 1/7/1998    3.7   3.2          2.697745          2.579086
# ...         ...   ...               ...               ...
# 9/21/2003   1.5   1.1          1.807925          1.674507
# 9/22/2003   1.2   1.3          1.489603          1.376350
# 9/23/2003   0.2   0.2          1.425003          1.333773
# 9/24/2003   0.3   0.2          1.184023          1.239001
# 9/25/2003   0.2   0.2          0.970732          0.840566
#
# [1477 rows x 4 columns]

# %%
testvspred[['WSR0','WSR0 Predictions']].plot()
# Out:
# <AxesSubplot:>

# %%
testvspred[['WSR1','WSR1 Predictions']].plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(testvspred['WSR1'],testvspred['WSR1 Predictions'])
# Out:
# 1.4015852643654925

# %%
mean_squared_error(testvspred['WSR0'],testvspred['WSR0 Predictions'])
# Out:
# 1.418973110752442
