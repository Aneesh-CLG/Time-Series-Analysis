# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("births.csv", parse_dates=[0], index_col=0)
if data.shape[1] == 1: 
    data = data.iloc[:, 0]  

print(data.head())
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: Births, dtype: int64

# %%
data.head(6)
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# Name: Births, dtype: int64

# %%
data.tail(5)
# Out:
# Date
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: Births, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 365 entries, 1959-01-01 to 1959-12-31
# Series name: Births
# Non-Null Count  Dtype
# --------------  -----
# 365 non-null    int64
# dtypes: int64(1)
# memory usage: 5.7 KB

# %%
size = data.size
print("size of the data:",size)
# Out:
# size of the data: 365

# %%
print(data['1959-01'])
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: Births, dtype: int64

# %%
data.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Births, dtype: float64

# %%
plt.figure(figsize = (20,7))
plt.plot(data, color = 'green', marker = 'o', linestyle = '--', markerfacecolor='red')
plt.title("No. of Births based on dates")
plt.xlabel("Dates")
plt.ylabel("No. of Births")
plt.show()
